// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
int S = 200;
int N = 5;
float J = 1.0f;
float parcela = 0;
parcela = S;

for (int count = 1; count <= 5; count++){
    if (count > 1)
        parcela = parcela * (1 + J/100);
    System.out.println("Parcela " + count + ": " + parcela);
}
// Out:
// Parcela 1: 200.0
// Parcela 2: 202.0
// Parcela 3: 204.02
// Parcela 4: 206.0602
// Parcela 5: 208.12079
// null

// %%
System.out.println(5/2);

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class emprestimo {
    
    static float proximaParcela(float parcela, float J){
        
        parcela = parcela = parcela * (1 + J/100);
        
        return parcela;
    }
    
    
}
// Out:
// com.twosigma.beaker.javash.bkrb983610c.emprestimo

// %%
int S = 200;
int N = 5;
float J = 1.0f;
float parcela = 0;
parcela = S;

for (int count = 1; count <= 5; count++){
    if (count > 1)
        parcela = emprestimo.proximaParcela(parcela,J);
    System.out.println("Parcela " + count + ": " + parcela);
}
// Out:
// Parcela 1: 200.0
// Parcela 2: 202.0
// Parcela 3: 204.02
// Parcela 4: 206.0602
// Parcela 5: 208.12079
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Converter {
    static int[] binaryConverter(int n){
        int[] bin = new int[14];
        int aux;
        int pos = 0;
        while (n>1){
            aux = n/2;
            bin[pos] = n-aux*2;
            n = aux;
            pos++;
        }
        bin[pos] = n;
        return bin;
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkr73d0cce7.Converter

// %%
import java.util.Random;  // Import the Scanner class


    
Random rand = new Random();
int[] bin = new int[14];
int randomNumber = rand.nextInt(10000);
System.out.println("Em decimal: " + randomNumber);
bin = Converter.binaryConverter(randomNumber);
System.out.print("Em binario: ");
for (int count = 13; count>=0; count--){
    System.out.print(bin[count]);
}
// Out:
// Em decimal: 6397
// Em binario: 01100011111101
// null

// %%
System.out.println("O dinossauro pulou na lama");
// Out:
// O dinossauro pulou na lama
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.
//
// RNA ; DNA
// A ; T
// U ; A
// C ; G
// G ; C

// %%
public class RNAMachine{
    static String generateRNA (String DNA){
        String RNA = "";
        for (int count = 0; count < DNA.length(); count ++){
            switch(DNA.charAt(count)){
                case 'T': RNA = RNA + 'A'; break;
                case 'A': RNA = RNA + 'U'; break;
                case 'G': RNA = RNA + 'C'; break;
                case 'C': RNA = RNA + 'G'; break;
            }
            
        }
        return RNA;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr73d0cce7.RNAMachine

// %%
String DNA = "ATTACGCGCAAAC";
String RNA;
RNA = RNAMachine.generateRNA(DNA);
System.out.println ("DNA: "+DNA);
System.out.println ("RNA: "+RNA);
// Out:
// DNA: ATTACGCGCAAAC
// RNA: UAAUGCGCGUUUG
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;
Random r = new Random();
float min = 2500;
float max = 15000;
float[] salary = new float[50];
float average = 0;
int boss = 0; 
for (int count = 0; count < 50; count++){
    salary[count] = r.nextFloat()*(max-min) + min; 
    average += salary[count];
    System.out.println(salary[count]);
}
average /= salary.length;
for (int count = 0; count < 50; count++){
    if (salary[count] > average) {
        System.out.println(salary[count]);
        boss++;
    }   
}
System.out.println("I found: " + boss + " bosses in this list which have a salary bigger than " + average);
// Out:
// 14190.874
// 14229.624
// 14816.004
// 3160.713
// 4935.91
// 10467.33
// 9594.828
// 12622.875
// 2595.2988
// 14591.003
// 13198.251
// 5922.8604
// 4829.0527
// 14096.9
// 6930.6313
// 14638.448
// 3847.9092
// 14351.574
// 5635.747
// 8294.113
// 6813.1904
// 12517.495
// 6397.367
// 12008.045
// 8880.373
// 14524.12
// 5779.323
// 14801.802
// 6409.331
// 14474.197
// 3050.6306
// 11232.905
// 11527.976
// 7368.489
// 8259.592
// 11184.236
// 9144.436
// 11240.1045
// 4956.5186
// 7132.391
// 3687.7275
// 10921.945
// 12400.294
// 5764.574
// 10232.645
// 12163.295
// 10997.35
// 8454.018
// 11153.658
// 6452.0347
// 14190.874
// 14229.624
// 14816.004
// 10467.33
// 9594.828
// 12622.875
// 14591.003
// 13198.251
// 14096.9
// 14638.448
// 14351.574
// 12517.495
// 12008.045
// 14524.12
// 14801.802
// 14474.197
// 11232.905
// 11527.976
// 11184.236
// 11240.1045
// 10921.945
// 12400.294
// 10232.645
// 12163.295
// 10997.35
// 11153.658
// I found: 26 bosses in this list which have a salary bigger than 9457.601
// null
